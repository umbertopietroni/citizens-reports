# %%
import pandas as pd
segnalazioni = pd.read_csv('testset.csv',low_memory=False)

# %%
segnalazioni.head()
# Out:
#                                                 text  class     infoclass  \
# 0  La presente per segnalare la presenza di un ca...      3  Manutenzione
# 1  Richiesta installazione specchio fra via Osima...      3  Manutenzione
# 2  dopo alcune ore la situazione nei pressi dei c...      1      Ambiente
# 3  Vorrei segnalare il fatto che nella Via Monte ...      4     Sicurezza
# 4  Buongiorno  sono lieta che finalmente sia stat...      4     Sicurezza
#
#        city
# 0    negrar
# 1  camerano
# 2  cagliari
# 3  cagliari
# 4  volpiano

# %%
segnalazioni.shape
# Out:
# (1680, 4)

# %%
segnalazioni["infoclass"].value_counts()
# Out:
# Sicurezza        431
# Illuminazione    421
# Manutenzione     420
# Ambiente         408
# Name: infoclass, dtype: int64

# %%
pd.set_option('display.max_colwidth', -1)
segnalazioni.loc[segnalazioni['label'] == "Igiene_del_Suolo___Polizia_Municipale__"]
# Out:
#              id  \
# 472   1129.html
# 504   0574.html
# 548   0869.html
# 580   0370.html
# 660   0562.html
# 804   1514.html
# 856   0904.html
# 897   1042.html
# 905   1062.html
# 1033  0481.html
# 1251  1099.html
# 1282  0205.html
# 1396  0183.html
# 1633  1563.html
# 1696  1363.html
# 1779  0928.html
# 1813  0770.html
# 1871  1153.html
# 1976  1386.html
# 2074  0356.html
# 2079  0897.html
# 2112  0468.html
# 2179  0872.html
# 2236  1590.html
#
# ...
